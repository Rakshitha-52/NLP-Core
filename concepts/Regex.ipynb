# %%
import re

# %%
chat1='akjdhha 123239 kajdje@gmail.com'
chat2= 'klfj;ohf654864 lwejhfjhefh@gmail.in'
chat3= 'glruigfg (356)-554-654 rghrg@ouutlook.com'

re.findall('[a-z0-9A-Z_]*@[a-z0-9A-Z_]*\.[a-z0-9A-Z_]*',chat1)
re.findall('\d{6}|\(\d{3}\)-\d{3}-\d{3}', chat2)
# Out:
# ['654864']
