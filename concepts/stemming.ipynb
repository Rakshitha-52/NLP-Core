# %%
import nltk
import spacy

from nltk.stem import PorterStemmer
stemmer=PorterStemmer()

# %%
words=["eating","eats","eat","ate","adjustable","rafting","ability","meeting"]

for word in words:
    print(word,"|", stemmer.stem(word))
# Out:
# eating | eat
# eats | eat
# eat | eat
# ate | ate
# adjustable | adjust
# rafting | raft
# ability | abil
# meeting | meet

# %%
nlp=spacy.load("en_core_web_sm")

doc=nlp("eating eat eat ate adjustable rafting ability meeting better")

for token in doc:
    print(token,"|", token.lemma_,"|", token.lemma)
# Out:
# eating | eat | 9837207709914848172
# eat | eat | 9837207709914848172
# eat | eat | 9837207709914848172
# ate | eat | 9837207709914848172
# adjustable | adjustable | 6033511944150694480
# rafting | raft | 7154368781129989833
# ability | ability | 11565809527369121409
# meeting | meet | 6880656908171229526
# better | well | 4525988469032889948

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x249867c0830>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x249867c0a10>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x249864fec70>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x249867ea2d0>),
#  ('lemmatizer', <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x2498678f990>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x249864fec00>)]

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
#customising words
ar=nlp.get_pipe('attribute_ruler')
ar.add([[{"text":"bro"}],[{"text":"brahh"}]],{"LEMMA":"brother"})
dpc=nlp("bro, r u up, brahh plz say yes")
for token in dpc:
    print(token.text,"|",token.lemma_)
# Out:
# bro | brother
# , | ,
# r | r
# u | u
# up | up
# , | ,
# brahh | brother
# plz | plz
# say | say
# yes | yes
